# %% [markdown]
# <a href="https://colab.research.google.com/github/AlfredoMarino/cifar10/blob/main/Copia_de_cnn_cifar10_tf2_v7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
import random

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
#reshape into images
#img_rows, img_cols , channels= 32,32,3
#x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
#x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)
#input_shape = (img_rows, img_cols, 1)
#print('x_train shape:', x_train.shape)
#print(x_train.shape[0], 'train samples')
#print(x_test.shape[0], 'test samples')

# %%
#Normalizaremos
#mean = np.mean(x_train)
#std = np.std(x_train)

#x_train_scaled = (x_train - mean) / (std + 1e-7)
#x_test_scaled = (x_test - mean) / (std + 1e-7)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
y_test
# Out:
# array([[3],
#        [8],
#        [8],
#        ...,
#        [5],
#        [1],
#        [7]], dtype=uint8)

# %%
y_train = y_train.ravel()
y_test = y_test.ravel()

print("y_train", y_train)
print("y_test", y_test)
# Out:
# y_train [6 9 9 ... 9 1 1]
# y_test [3 8 8 ... 5 1 7]

# %%
y_train_label = y_train

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
  'airplane', # id 0
  'automobile',
  'bird',
  'cat',
  'deer',
  'dog',
  'frog',
  'horse',
  'ship',
  'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset CIFAR10

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ### Vemos ejemplos del data augumentation

# %%
train_batch_size = 32
val_batch_size = 20

# %%
# Data augmentation

train_datagen = ImageDataGenerator(
    rescale=(1./255),
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
)

train_generator = train_datagen.flow(
    x_train,
    y_train,
    batch_size=train_batch_size
)

validation_datagen = ImageDataGenerator(
    rescale=(1./255)
)

validation_generator = validation_datagen.flow(
    x_val,
    y_val,
    batch_size=val_batch_size
)

# %%
sample = random.choice(range(0,1457))

example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=20
)

plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Arquitectura de red del modelo - Proyecto 0

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32,32,3)))

model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_2 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_3 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 10)                20490
#
# =================================================================
# Total params: 456,490
# Trainable params: 455,786
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# ## 4. Optimizador, función error

# %%
model.compile(
    optimizer='Adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# callback EarlyStopping basado en Accuracy
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience=10)

# callback EarlyStopping basadon en Loss
callback_loss = EarlyStopping(monitor='val_loss', patience=5)

# callback ModelCheckpoint basado en Accuracy
callback_checkpoint = ModelCheckpoint('best_cifa10.hdf5', verbose=1, save_best_only=True, monitor = 'val_accuracy')

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
print(f"x_train.shape[0]: {x_train.shape[0]}")
print(f"x_val.shape[0]: {x_val.shape[0]}")
# Out:
# x_train.shape[0]: 40000
# x_val.shape[0]: 10000

# %%
step_per_epoch=x_train.shape[0] / train_batch_size
validation_steps=x_val.shape[0] / val_batch_size

print(f"step_per_epoch: {step_per_epoch}")
print(f"validation_steps: {validation_steps}")
# Out:
# step_per_epoch: 1250.0
# validation_steps: 500.0

# %%
history = model.fit(
    train_generator,
    epochs=200,
    validation_data=validation_generator,
    steps_per_epoch=x_train.shape[0] // train_batch_size,
    validation_steps=x_val.shape[0] // val_batch_size,
    callbacks=[callback_checkpoint, callback_loss, callback_accuracy]
)
# Out:
# Epoch 1/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 2.0123 - accuracy: 0.3134
# Epoch 1: val_accuracy improved from -inf to 0.29850, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 21ms/step - loss: 2.0120 - accuracy: 0.3135 - val_loss: 1.9624 - val_accuracy: 0.2985
# Epoch 2/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.5789 - accuracy: 0.4227
# Epoch 2: val_accuracy improved from 0.29850 to 0.41510, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.5789 - accuracy: 0.4227 - val_loss: 1.5626 - val_accuracy: 0.4151
# Epoch 3/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.4533 - accuracy: 0.4707
# Epoch 3: val_accuracy improved from 0.41510 to 0.51180, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.4533 - accuracy: 0.4708 - val_loss: 1.3255 - val_accuracy: 0.5118
# Epoch 4/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.3516 - accuracy: 0.5159
# Epoch 4: val_accuracy did not improve from 0.51180
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.3516 - accuracy: 0.5159 - val_loss: 1.4068 - val_accuracy: 0.4800
# Epoch 5/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2812 - accuracy: 0.5424
# Epoch 5: val_accuracy improved from 0.51180 to 0.60300, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.2813 - accuracy: 0.5423 - val_loss: 1.1419 - val_accuracy: 0.6030
# Epoch 6/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.2118 - accuracy: 0.5687
# Epoch 6: val_accuracy improved from 0.60300 to 0.60660, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.2118 - accuracy: 0.5687 - val_loss: 1.1141 - val_accuracy: 0.6066
# Epoch 7/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.1773 - accuracy: 0.5847
# Epoch 7: val_accuracy did not improve from 0.60660
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.1770 - accuracy: 0.5848 - val_loss: 1.3166 - val_accuracy: 0.5573
# Epoch 8/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1360 - accuracy: 0.5954
# Epoch 8: val_accuracy improved from 0.60660 to 0.61620, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.1360 - accuracy: 0.5954 - val_loss: 1.0761 - val_accuracy: 0.6162
# Epoch 9/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1039 - accuracy: 0.6083
# Epoch 9: val_accuracy improved from 0.61620 to 0.63310, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.1038 - accuracy: 0.6083 - val_loss: 1.0270 - val_accuracy: 0.6331
# Epoch 10/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0721 - accuracy: 0.6205
# Epoch 10: val_accuracy did not improve from 0.63310
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.0720 - accuracy: 0.6205 - val_loss: 1.1848 - val_accuracy: 0.5964
# Epoch 11/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0501 - accuracy: 0.6281
# Epoch 11: val_accuracy improved from 0.63310 to 0.65560, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.0500 - accuracy: 0.6280 - val_loss: 0.9652 - val_accuracy: 0.6556
# Epoch 12/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.0263 - accuracy: 0.6385
# Epoch 12: val_accuracy improved from 0.65560 to 0.67950, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.0265 - accuracy: 0.6385 - val_loss: 0.8978 - val_accuracy: 0.6795
# Epoch 13/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.0059 - accuracy: 0.6446
# Epoch 13: val_accuracy improved from 0.67950 to 0.68590, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.0064 - accuracy: 0.6444 - val_loss: 0.8614 - val_accuracy: 0.6859
# Epoch 14/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9858 - accuracy: 0.6513
# Epoch 14: val_accuracy did not improve from 0.68590
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.9858 - accuracy: 0.6513 - val_loss: 0.9962 - val_accuracy: 0.6536
# Epoch 15/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9628 - accuracy: 0.6599
# Epoch 15: val_accuracy improved from 0.68590 to 0.69800, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.9628 - accuracy: 0.6599 - val_loss: 0.8446 - val_accuracy: 0.6980
# Epoch 16/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9506 - accuracy: 0.6651
# Epoch 16: val_accuracy did not improve from 0.69800
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.9506 - accuracy: 0.6651 - val_loss: 1.0334 - val_accuracy: 0.6438
# Epoch 17/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9303 - accuracy: 0.6719
# Epoch 17: val_accuracy did not improve from 0.69800
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.9303 - accuracy: 0.6719 - val_loss: 0.8762 - val_accuracy: 0.6896
# Epoch 18/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9218 - accuracy: 0.6754
# Epoch 18: val_accuracy did not improve from 0.69800
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.9218 - accuracy: 0.6754 - val_loss: 0.9303 - val_accuracy: 0.6824
# Epoch 19/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9104 - accuracy: 0.6821
# Epoch 19: val_accuracy did not improve from 0.69800
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.9108 - accuracy: 0.6819 - val_loss: 0.9525 - val_accuracy: 0.6580
# Epoch 20/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9022 - accuracy: 0.6846
# Epoch 20: val_accuracy improved from 0.69800 to 0.70310, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.9022 - accuracy: 0.6846 - val_loss: 0.8658 - val_accuracy: 0.7031

# %%
#history = model.fit(
#    x_train_scaled,
#    y_train,
#    epochs=100,
#    use_multiprocessing=False,
#    batch_size=128,
#    validation_data=(x_val_scaled, y_val),
#    callbacks=[callback_loss, callback_accuracy]
#)

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:14:46.236126

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 69.730

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Colab Notebooks/h5_backups/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
