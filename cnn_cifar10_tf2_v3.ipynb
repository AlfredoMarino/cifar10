# %% [markdown]
# <a href="https://colab.research.google.com/github/AlfredoMarino/cifar10/blob/main/cnn_cifar10_tf2_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import RMSprop, SGD
from keras.models import load_model

from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
import random

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
#reshape into images
#img_rows, img_cols , channels= 32,32,3
#x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
#x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)
#input_shape = (img_rows, img_cols, 1)
#print('x_train shape:', x_train.shape)
#print(x_train.shape[0], 'train samples')
#print(x_test.shape[0], 'test samples')

# %%
#Normalizaremos
#mean = np.mean(x_train)
#std = np.std(x_train)

#x_train_scaled = (x_train - mean) / (std + 1e-7)
#x_test_scaled = (x_test - mean) / (std + 1e-7)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
y_test
# Out:
# array([[3],
#        [8],
#        [8],
#        ...,
#        [5],
#        [1],
#        [7]], dtype=uint8)

# %%
y_train = y_train.ravel()
y_test = y_test.ravel()

print("y_train", y_train)
print("y_test", y_test)
# Out:
# y_train [6 9 9 ... 9 1 1]
# y_test [3 8 8 ... 5 1 7]

# %%
y_train_label = y_train

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
  'airplane', # id 0
  'automobile',
  'bird',
  'cat',
  'deer',
  'dog',
  'frog',
  'horse',
  'ship',
  'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset CIFAR10

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ### Vemos ejemplos del data augumentation

# %%
train_batch_size = 32
val_batch_size = 20

# %%
# Data augmentation

train_datagen = ImageDataGenerator(
    rescale=(1./255),
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
)

train_generator = train_datagen.flow(
    x_train,
    y_train,
    batch_size=train_batch_size
)

validation_datagen = ImageDataGenerator(
    rescale=(1./255)
)

validation_generator = validation_datagen.flow(
    x_val,
    y_val,
    batch_size=val_batch_size
)

# %%
sample = random.choice(range(0,1457))

example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=20
)

plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Arquitectura de red del modelo - Proyecto 0

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32,32,3),
                 kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', 
                 kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same',
                  kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same',
                  kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same',
                  kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same',
                  kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same',
                  kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.4))

model.add(Conv2D(256, (3, 3), activation='relu', padding='same',
                  kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same',
                  kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same',
                  kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(256, activation='relu', kernel_initializer='he_uniform', 
                kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu', kernel_initializer='he_uniform', 
                kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_6 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 256)         295168
#
#  batch_normalization_7 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 4, 4, 256)         0
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 256)         590080
#
#  batch_normalization_8 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 4, 4, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 256)         590080
#
#  batch_normalization_9 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  batch_normalization_11 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 2,248,106
# Trainable params: 2,244,394
# Non-trainable params: 3,712
# _________________________________________________________________

# %% [markdown]
# ## 4. Optimizador, función error

# %%
#opt_rms = keras.optimizers.rmsprop(lr=0.001,decay=1e-6)

#opt_rms = RMSprop(momentum=0.9)


opt_sgd = SGD()

# %%
model.compile(
    optimizer=opt_sgd,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# callback EarlyStopping basado en Accuracy
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience=20)

# callback EarlyStopping basadon en Loss
callback_loss = EarlyStopping(monitor='val_loss', patience=20)

# callback ModelCheckpoint basado en Accuracy
callback_checkpoint = ModelCheckpoint('best_cifa10.hdf5', verbose=1, save_best_only=True, monitor = 'val_accuracy')

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
print(f"x_train.shape[0]: {x_train.shape[0]}")
print(f"x_val.shape[0]: {x_val.shape[0]}")
# Out:
# x_train.shape[0]: 40000
# x_val.shape[0]: 10000

# %%
print(f"step_per_epoch: {x_train.shape[0] // train_batch_size}")
print(f"validation_steps: {x_val.shape[0] // val_batch_size}")
# Out:
# step_per_epoch: 1250
# validation_steps: 500

# %%
history = model.fit(
    train_generator,
    epochs=200,
    validation_data=validation_generator,
    steps_per_epoch=x_train.shape[0] // train_batch_size,
    validation_steps=x_val.shape[0] // val_batch_size,
    callbacks=[callback_checkpoint, callback_loss, callback_accuracy]
)
# Out:
# Epoch 1/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2662 - accuracy: 0.7235
# Epoch 1: val_accuracy improved from -inf to 0.77720, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 32s 24ms/step - loss: 1.2666 - accuracy: 0.7234 - val_loss: 1.0924 - val_accuracy: 0.7772
# Epoch 2/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1944 - accuracy: 0.7392
# Epoch 2: val_accuracy did not improve from 0.77720
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.1946 - accuracy: 0.7390 - val_loss: 1.0855 - val_accuracy: 0.7717
# Epoch 3/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1525 - accuracy: 0.7476
# Epoch 3: val_accuracy improved from 0.77720 to 0.78130, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.1525 - accuracy: 0.7476 - val_loss: 1.0392 - val_accuracy: 0.7813
# Epoch 4/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1173 - accuracy: 0.7541
# Epoch 4: val_accuracy improved from 0.78130 to 0.78630, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.1173 - accuracy: 0.7541 - val_loss: 1.0162 - val_accuracy: 0.7863
# Epoch 5/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0835 - accuracy: 0.7625
# Epoch 5: val_accuracy improved from 0.78630 to 0.79190, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.0835 - accuracy: 0.7625 - val_loss: 0.9790 - val_accuracy: 0.7919
# Epoch 6/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.0645 - accuracy: 0.7626
# Epoch 6: val_accuracy did not improve from 0.79190
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.0644 - accuracy: 0.7625 - val_loss: 1.0255 - val_accuracy: 0.7733
# Epoch 7/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0383 - accuracy: 0.7664
# Epoch 7: val_accuracy did not improve from 0.79190
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.0383 - accuracy: 0.7664 - val_loss: 0.9622 - val_accuracy: 0.7886
# Epoch 8/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0104 - accuracy: 0.7710
# Epoch 8: val_accuracy improved from 0.79190 to 0.80230, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 24ms/step - loss: 1.0101 - accuracy: 0.7711 - val_loss: 0.9143 - val_accuracy: 0.8023
# Epoch 9/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0051 - accuracy: 0.7683
# Epoch 9: val_accuracy did not improve from 0.80230
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.0051 - accuracy: 0.7683 - val_loss: 0.9193 - val_accuracy: 0.7946
# Epoch 10/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9868 - accuracy: 0.7684
# Epoch 10: val_accuracy did not improve from 0.80230
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.9868 - accuracy: 0.7684 - val_loss: 0.9026 - val_accuracy: 0.7992
# Epoch 11/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9662 - accuracy: 0.7726
# Epoch 11: val_accuracy did not improve from 0.80230
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.9660 - accuracy: 0.7727 - val_loss: 0.9552 - val_accuracy: 0.7820
# Epoch 12/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9558 - accuracy: 0.7740
# Epoch 12: val_accuracy improved from 0.80230 to 0.81870, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.9558 - accuracy: 0.7739 - val_loss: 0.8286 - val_accuracy: 0.8187
# Epoch 13/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9390 - accuracy: 0.7767
# Epoch 13: val_accuracy did not improve from 0.81870
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.9390 - accuracy: 0.7767 - val_loss: 0.9421 - val_accuracy: 0.7826
# Epoch 14/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9271 - accuracy: 0.7773
# Epoch 14: val_accuracy did not improve from 0.81870
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.9272 - accuracy: 0.7772 - val_loss: 0.8608 - val_accuracy: 0.8028
# Epoch 15/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9153 - accuracy: 0.7796
# Epoch 15: val_accuracy did not improve from 0.81870
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.9155 - accuracy: 0.7795 - val_loss: 0.8529 - val_accuracy: 0.7999
# Epoch 16/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9098 - accuracy: 0.7779
# Epoch 16: val_accuracy did not improve from 0.81870
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.9100 - accuracy: 0.7778 - val_loss: 0.8116 - val_accuracy: 0.8112
# Epoch 17/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9055 - accuracy: 0.7787
# Epoch 17: val_accuracy did not improve from 0.81870
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.9051 - accuracy: 0.7789 - val_loss: 0.8116 - val_accuracy: 0.8076
# Epoch 18/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8934 - accuracy: 0.7804
# Epoch 18: val_accuracy did not improve from 0.81870
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8934 - accuracy: 0.7804 - val_loss: 0.8466 - val_accuracy: 0.7940
# Epoch 19/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8847 - accuracy: 0.7822
# Epoch 19: val_accuracy did not improve from 0.81870
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8846 - accuracy: 0.7823 - val_loss: 0.8066 - val_accuracy: 0.8073
# Epoch 20/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8823 - accuracy: 0.7807
# Epoch 20: val_accuracy did not improve from 0.81870
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8823 - accuracy: 0.7807 - val_loss: 0.8016 - val_accuracy: 0.8055
# Epoch 21/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8702 - accuracy: 0.7817
# Epoch 21: val_accuracy improved from 0.81870 to 0.82060, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8702 - accuracy: 0.7817 - val_loss: 0.7525 - val_accuracy: 0.8206
# Epoch 22/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8698 - accuracy: 0.7817
# Epoch 22: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8696 - accuracy: 0.7817 - val_loss: 0.8490 - val_accuracy: 0.7933
# Epoch 23/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8618 - accuracy: 0.7839
# Epoch 23: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8617 - accuracy: 0.7839 - val_loss: 0.7781 - val_accuracy: 0.8110
# Epoch 24/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8629 - accuracy: 0.7833
# Epoch 24: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8629 - accuracy: 0.7833 - val_loss: 0.8137 - val_accuracy: 0.8006
# Epoch 25/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8530 - accuracy: 0.7860
# Epoch 25: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8528 - accuracy: 0.7861 - val_loss: 0.7666 - val_accuracy: 0.8155
# Epoch 26/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8523 - accuracy: 0.7834
# Epoch 26: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8524 - accuracy: 0.7834 - val_loss: 0.8891 - val_accuracy: 0.7751
# Epoch 27/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8525 - accuracy: 0.7853
# Epoch 27: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8524 - accuracy: 0.7853 - val_loss: 0.8814 - val_accuracy: 0.7784
# Epoch 28/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8524 - accuracy: 0.7810
# Epoch 28: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8523 - accuracy: 0.7810 - val_loss: 0.7802 - val_accuracy: 0.8058
# Epoch 29/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8453 - accuracy: 0.7885
# Epoch 29: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8452 - accuracy: 0.7885 - val_loss: 0.8001 - val_accuracy: 0.8022
# Epoch 30/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8390 - accuracy: 0.7879
# Epoch 30: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8391 - accuracy: 0.7879 - val_loss: 0.7554 - val_accuracy: 0.8155
# Epoch 31/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8438 - accuracy: 0.7832
# Epoch 31: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8438 - accuracy: 0.7832 - val_loss: 0.8738 - val_accuracy: 0.7851
# Epoch 32/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8413 - accuracy: 0.7853
# Epoch 32: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8413 - accuracy: 0.7853 - val_loss: 0.7992 - val_accuracy: 0.8033
# Epoch 33/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8315 - accuracy: 0.7917
# Epoch 33: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8314 - accuracy: 0.7917 - val_loss: 0.8035 - val_accuracy: 0.8043
# Epoch 34/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8311 - accuracy: 0.7882
# Epoch 34: val_accuracy did not improve from 0.82060
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8311 - accuracy: 0.7882 - val_loss: 0.8169 - val_accuracy: 0.7958
# Epoch 35/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8420 - accuracy: 0.7877
# Epoch 35: val_accuracy improved from 0.82060 to 0.83220, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8420 - accuracy: 0.7877 - val_loss: 0.7013 - val_accuracy: 0.8322
# Epoch 36/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8413 - accuracy: 0.7851
# Epoch 36: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8412 - accuracy: 0.7851 - val_loss: 0.7869 - val_accuracy: 0.8045
# Epoch 37/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8302 - accuracy: 0.7873
# Epoch 37: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8303 - accuracy: 0.7873 - val_loss: 0.7244 - val_accuracy: 0.8253
# Epoch 38/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8307 - accuracy: 0.7904
# Epoch 38: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8309 - accuracy: 0.7904 - val_loss: 0.8467 - val_accuracy: 0.7901
# Epoch 39/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8398 - accuracy: 0.7881
# Epoch 39: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8398 - accuracy: 0.7881 - val_loss: 0.7630 - val_accuracy: 0.8144
# Epoch 40/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8299 - accuracy: 0.7904
# Epoch 40: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8300 - accuracy: 0.7903 - val_loss: 0.7910 - val_accuracy: 0.8041
# Epoch 41/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8298 - accuracy: 0.7897
# Epoch 41: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8298 - accuracy: 0.7897 - val_loss: 1.0855 - val_accuracy: 0.7305
# Epoch 42/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8335 - accuracy: 0.7910
# Epoch 42: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8333 - accuracy: 0.7910 - val_loss: 0.7942 - val_accuracy: 0.8074
# Epoch 43/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8274 - accuracy: 0.7888
# Epoch 43: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8276 - accuracy: 0.7887 - val_loss: 0.7861 - val_accuracy: 0.8077
# Epoch 44/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8278 - accuracy: 0.7922
# Epoch 44: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8274 - accuracy: 0.7923 - val_loss: 0.7245 - val_accuracy: 0.8259
# Epoch 45/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8236 - accuracy: 0.7924
# Epoch 45: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8232 - accuracy: 0.7925 - val_loss: 0.7211 - val_accuracy: 0.8272
# Epoch 46/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8227 - accuracy: 0.7939
# Epoch 46: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8226 - accuracy: 0.7939 - val_loss: 0.8204 - val_accuracy: 0.8059
# Epoch 47/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8262 - accuracy: 0.7933
# Epoch 47: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8262 - accuracy: 0.7932 - val_loss: 0.7640 - val_accuracy: 0.8165
# Epoch 48/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8230 - accuracy: 0.7957
# Epoch 48: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8229 - accuracy: 0.7957 - val_loss: 0.7488 - val_accuracy: 0.8224
# Epoch 49/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8261 - accuracy: 0.7921
# Epoch 49: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8261 - accuracy: 0.7921 - val_loss: 0.7766 - val_accuracy: 0.8066
# Epoch 50/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8183 - accuracy: 0.7942
# Epoch 50: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8182 - accuracy: 0.7942 - val_loss: 0.7469 - val_accuracy: 0.8240
# Epoch 51/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8286 - accuracy: 0.7943
# Epoch 51: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8287 - accuracy: 0.7943 - val_loss: 0.7300 - val_accuracy: 0.8286
# Epoch 52/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8238 - accuracy: 0.7942
# Epoch 52: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8237 - accuracy: 0.7943 - val_loss: 0.8593 - val_accuracy: 0.7915
# Epoch 53/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8212 - accuracy: 0.7967
# Epoch 53: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8210 - accuracy: 0.7967 - val_loss: 0.8968 - val_accuracy: 0.7759
# Epoch 54/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8251 - accuracy: 0.7954
# Epoch 54: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.8251 - accuracy: 0.7954 - val_loss: 0.7705 - val_accuracy: 0.8192
# Epoch 55/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8226 - accuracy: 0.7965
# Epoch 55: val_accuracy did not improve from 0.83220
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8227 - accuracy: 0.7965 - val_loss: 0.7253 - val_accuracy: 0.8264

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:27:13.740161

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
saved_model = load_model("best_cifa10.hdf5")
_, acc = saved_model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 82.860

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 82.180

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = saved_model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Colab Notebooks/h5_backups/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
