# %% [markdown]
# <a href="https://colab.research.google.com/github/AlfredoMarino/cifar10/blob/main/cnn_cifar10_tf2_v9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from keras.models import load_model

from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
import random

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
#reshape into images
#img_rows, img_cols , channels= 32,32,3
#x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
#x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)
#input_shape = (img_rows, img_cols, 1)
#print('x_train shape:', x_train.shape)
#print(x_train.shape[0], 'train samples')
#print(x_test.shape[0], 'test samples')

# %%
#Normalizaremos
#mean = np.mean(x_train)
#std = np.std(x_train)

#x_train_scaled = (x_train - mean) / (std + 1e-7)
#x_test_scaled = (x_test - mean) / (std + 1e-7)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
y_test
# Out:
# array([[3],
#        [8],
#        [8],
#        ...,
#        [5],
#        [1],
#        [7]], dtype=uint8)

# %%
y_train = y_train.ravel()
y_test = y_test.ravel()

print("y_train", y_train)
print("y_test", y_test)
# Out:
# y_train [6 9 9 ... 9 1 1]
# y_test [3 8 8 ... 5 1 7]

# %%
y_train_label = y_train

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
  'airplane', # id 0
  'automobile',
  'bird',
  'cat',
  'deer',
  'dog',
  'frog',
  'horse',
  'ship',
  'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset CIFAR10

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ### Vemos ejemplos del data augumentation

# %%
train_batch_size = 32
val_batch_size = 20

# %%
# Data augmentation

train_datagen = ImageDataGenerator(
    rescale=(1./255),
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
)

train_generator = train_datagen.flow(
    x_train,
    y_train,
    batch_size=train_batch_size
)

validation_datagen = ImageDataGenerator(
    rescale=(1./255)
)

validation_generator = validation_datagen.flow(
    x_val,
    y_val,
    batch_size=val_batch_size
)

# %%
sample = random.choice(range(0,1457))

example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=20
)

plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Arquitectura de red del modelo - Proyecto 0

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32,32,3),
                 kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.4))

model.add(Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(256, activation='relu', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_47 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_36 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  conv2d_48 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_37 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  max_pooling2d_19 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  dropout_34 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_49 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_38 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  conv2d_50 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_39 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  max_pooling2d_20 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  dropout_35 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_51 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_40 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  dropout_36 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_52 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_41 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  dropout_37 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_53 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_42 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_21 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  dropout_38 (Dropout)        (None, 4, 4, 128)         0
#
#  conv2d_54 (Conv2D)          (None, 4, 4, 256)         295168
#
#  batch_normalization_43 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  dropout_39 (Dropout)        (None, 4, 4, 256)         0
#
#  conv2d_55 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_44 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  dropout_40 (Dropout)        (None, 4, 4, 256)         0
#
#  conv2d_56 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_45 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  max_pooling2d_22 (MaxPoolin  (None, 2, 2, 256)        0
#  g2D)
#
#  dropout_41 (Dropout)        (None, 2, 2, 256)         0
#
#  flatten_5 (Flatten)         (None, 1024)              0
#
#  dense_11 (Dense)            (None, 256)               262400
#
#  batch_normalization_46 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_42 (Dropout)        (None, 256)               0
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  batch_normalization_47 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_13 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 2,248,106
# Trainable params: 2,244,394
# Non-trainable params: 3,712
# _________________________________________________________________

# %% [markdown]
# ## 4. Optimizador, función error

# %%
model.compile(
    optimizer='Adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# callback EarlyStopping basado en Accuracy
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience=5)

# callback EarlyStopping basadon en Loss
callback_loss = EarlyStopping(monitor='val_loss', patience=5)

# callback ModelCheckpoint basado en Accuracy
callback_checkpoint = ModelCheckpoint('best_cifa10.hdf5', verbose=1, save_best_only=True, monitor = 'val_accuracy')

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
print(f"x_train.shape[0]: {x_train.shape[0]}")
print(f"x_val.shape[0]: {x_val.shape[0]}")
# Out:
# x_train.shape[0]: 40000
# x_val.shape[0]: 10000

# %%
print(f"step_per_epoch: {x_train.shape[0] // train_batch_size}")
print(f"validation_steps: {x_val.shape[0] // val_batch_size}")
# Out:
# step_per_epoch: 1250
# validation_steps: 500

# %%
history = model.fit(
    train_generator,
    epochs=200,
    validation_data=validation_generator,
    steps_per_epoch=x_train.shape[0] // train_batch_size,
    validation_steps=x_val.shape[0] // val_batch_size,
    callbacks=[callback_checkpoint, callback_loss, callback_accuracy]
)
# Out:
# Epoch 1/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.9086 - accuracy: 0.2965
# Epoch 1: val_accuracy improved from -inf to 0.38860, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 32s 24ms/step - loss: 1.9084 - accuracy: 0.2966 - val_loss: 1.7029 - val_accuracy: 0.3886
# Epoch 2/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.5836 - accuracy: 0.4125
# Epoch 2: val_accuracy improved from 0.38860 to 0.41340, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.5836 - accuracy: 0.4125 - val_loss: 1.7748 - val_accuracy: 0.4134
# Epoch 3/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.4210 - accuracy: 0.4858
# Epoch 3: val_accuracy improved from 0.41340 to 0.52250, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 31s 25ms/step - loss: 1.4210 - accuracy: 0.4859 - val_loss: 1.3882 - val_accuracy: 0.5225
# Epoch 4/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.2961 - accuracy: 0.5339
# Epoch 4: val_accuracy did not improve from 0.52250
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.2958 - accuracy: 0.5339 - val_loss: 1.5004 - val_accuracy: 0.5151
# Epoch 5/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2114 - accuracy: 0.5685
# Epoch 5: val_accuracy improved from 0.52250 to 0.56690, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.2113 - accuracy: 0.5685 - val_loss: 1.2433 - val_accuracy: 0.5669
# Epoch 6/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1420 - accuracy: 0.5960
# Epoch 6: val_accuracy improved from 0.56690 to 0.56960, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.1420 - accuracy: 0.5961 - val_loss: 1.2765 - val_accuracy: 0.5696
# Epoch 7/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0831 - accuracy: 0.6183
# Epoch 7: val_accuracy improved from 0.56960 to 0.64300, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.0830 - accuracy: 0.6184 - val_loss: 1.0147 - val_accuracy: 0.6430
# Epoch 8/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.0316 - accuracy: 0.6338
# Epoch 8: val_accuracy did not improve from 0.64300
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.0314 - accuracy: 0.6339 - val_loss: 1.1061 - val_accuracy: 0.6192
# Epoch 9/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9913 - accuracy: 0.6520
# Epoch 9: val_accuracy improved from 0.64300 to 0.66410, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.9913 - accuracy: 0.6521 - val_loss: 0.9720 - val_accuracy: 0.6641
# Epoch 10/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9579 - accuracy: 0.6633
# Epoch 10: val_accuracy improved from 0.66410 to 0.67210, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.9579 - accuracy: 0.6633 - val_loss: 0.9243 - val_accuracy: 0.6721
# Epoch 11/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9260 - accuracy: 0.6755
# Epoch 11: val_accuracy improved from 0.67210 to 0.69520, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.9261 - accuracy: 0.6755 - val_loss: 0.8544 - val_accuracy: 0.6952
# Epoch 12/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9037 - accuracy: 0.6842
# Epoch 12: val_accuracy improved from 0.69520 to 0.72620, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.9037 - accuracy: 0.6842 - val_loss: 0.7575 - val_accuracy: 0.7262
# Epoch 13/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8881 - accuracy: 0.6907
# Epoch 13: val_accuracy did not improve from 0.72620
# 1250/1250 [==============================] - 33s 27ms/step - loss: 0.8883 - accuracy: 0.6906 - val_loss: 0.8347 - val_accuracy: 0.6996
# Epoch 14/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8511 - accuracy: 0.7042
# Epoch 14: val_accuracy did not improve from 0.72620
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8511 - accuracy: 0.7042 - val_loss: 0.7833 - val_accuracy: 0.7259
# Epoch 15/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8401 - accuracy: 0.7092
# Epoch 15: val_accuracy improved from 0.72620 to 0.72880, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8398 - accuracy: 0.7092 - val_loss: 0.7621 - val_accuracy: 0.7288
# Epoch 16/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8255 - accuracy: 0.7138
# Epoch 16: val_accuracy improved from 0.72880 to 0.73930, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.8253 - accuracy: 0.7138 - val_loss: 0.7318 - val_accuracy: 0.7393
# Epoch 17/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8006 - accuracy: 0.7231
# Epoch 17: val_accuracy improved from 0.73930 to 0.74380, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8007 - accuracy: 0.7230 - val_loss: 0.7299 - val_accuracy: 0.7438
# Epoch 18/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7899 - accuracy: 0.7255
# Epoch 18: val_accuracy improved from 0.74380 to 0.76420, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.7897 - accuracy: 0.7256 - val_loss: 0.6644 - val_accuracy: 0.7642
# Epoch 19/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7751 - accuracy: 0.7296
# Epoch 19: val_accuracy did not improve from 0.76420
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.7749 - accuracy: 0.7297 - val_loss: 0.7745 - val_accuracy: 0.7347
# Epoch 20/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7595 - accuracy: 0.7363
# Epoch 20: val_accuracy did not improve from 0.76420
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.7591 - accuracy: 0.7365 - val_loss: 0.6849 - val_accuracy: 0.7569
# Epoch 21/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7484 - accuracy: 0.7431
# Epoch 21: val_accuracy did not improve from 0.76420
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.7484 - accuracy: 0.7431 - val_loss: 0.6663 - val_accuracy: 0.7624
# Epoch 22/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7370 - accuracy: 0.7449
# Epoch 22: val_accuracy did not improve from 0.76420
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.7371 - accuracy: 0.7449 - val_loss: 0.6786 - val_accuracy: 0.7598
# Epoch 23/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7257 - accuracy: 0.7494
# Epoch 23: val_accuracy improved from 0.76420 to 0.78010, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.7257 - accuracy: 0.7494 - val_loss: 0.6239 - val_accuracy: 0.7801
# Epoch 24/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7150 - accuracy: 0.7538
# Epoch 24: val_accuracy did not improve from 0.78010
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.7153 - accuracy: 0.7537 - val_loss: 0.7388 - val_accuracy: 0.7405
# Epoch 25/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7096 - accuracy: 0.7557
# Epoch 25: val_accuracy did not improve from 0.78010
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.7096 - accuracy: 0.7557 - val_loss: 0.8267 - val_accuracy: 0.7226
# Epoch 26/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6968 - accuracy: 0.7585
# Epoch 26: val_accuracy did not improve from 0.78010
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6968 - accuracy: 0.7585 - val_loss: 0.7123 - val_accuracy: 0.7599
# Epoch 27/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.7614
# Epoch 27: val_accuracy did not improve from 0.78010
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6940 - accuracy: 0.7614 - val_loss: 0.6540 - val_accuracy: 0.7664
# Epoch 28/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6846 - accuracy: 0.7648
# Epoch 28: val_accuracy improved from 0.78010 to 0.79590, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6846 - accuracy: 0.7648 - val_loss: 0.5785 - val_accuracy: 0.7959
# Epoch 29/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6782 - accuracy: 0.7658
# Epoch 29: val_accuracy did not improve from 0.79590
# 1250/1250 [==============================] - 29s 24ms/step - loss: 0.6781 - accuracy: 0.7658 - val_loss: 0.6747 - val_accuracy: 0.7707
# Epoch 30/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6719 - accuracy: 0.7674
# Epoch 30: val_accuracy did not improve from 0.79590
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6718 - accuracy: 0.7674 - val_loss: 0.6954 - val_accuracy: 0.7647
# Epoch 31/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6636 - accuracy: 0.7706
# Epoch 31: val_accuracy did not improve from 0.79590
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6636 - accuracy: 0.7706 - val_loss: 0.6419 - val_accuracy: 0.7784
# Epoch 32/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6566 - accuracy: 0.7719
# Epoch 32: val_accuracy improved from 0.79590 to 0.80010, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6570 - accuracy: 0.7718 - val_loss: 0.5720 - val_accuracy: 0.8001
# Epoch 33/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6461 - accuracy: 0.7744
# Epoch 33: val_accuracy improved from 0.80010 to 0.80700, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.6461 - accuracy: 0.7744 - val_loss: 0.5543 - val_accuracy: 0.8070
# Epoch 34/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6437 - accuracy: 0.7787
# Epoch 34: val_accuracy improved from 0.80700 to 0.80790, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 24ms/step - loss: 0.6437 - accuracy: 0.7787 - val_loss: 0.5672 - val_accuracy: 0.8079
# Epoch 35/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6403 - accuracy: 0.7791
# Epoch 35: val_accuracy improved from 0.80790 to 0.80820, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6402 - accuracy: 0.7792 - val_loss: 0.5661 - val_accuracy: 0.8082
# Epoch 36/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6338 - accuracy: 0.7827
# Epoch 36: val_accuracy did not improve from 0.80820
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6338 - accuracy: 0.7827 - val_loss: 0.6305 - val_accuracy: 0.7886
# Epoch 37/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6206 - accuracy: 0.7861
# Epoch 37: val_accuracy improved from 0.80820 to 0.81300, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6207 - accuracy: 0.7861 - val_loss: 0.5482 - val_accuracy: 0.8130
# Epoch 38/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6248 - accuracy: 0.7839
# Epoch 38: val_accuracy did not improve from 0.81300
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6248 - accuracy: 0.7839 - val_loss: 0.6075 - val_accuracy: 0.7874
# Epoch 39/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6192 - accuracy: 0.7883
# Epoch 39: val_accuracy did not improve from 0.81300
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6189 - accuracy: 0.7885 - val_loss: 0.5897 - val_accuracy: 0.8019
# Epoch 40/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.7887
# Epoch 40: val_accuracy did not improve from 0.81300
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6152 - accuracy: 0.7887 - val_loss: 0.5402 - val_accuracy: 0.8119
# Epoch 41/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6092 - accuracy: 0.7860
# Epoch 41: val_accuracy did not improve from 0.81300
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6092 - accuracy: 0.7860 - val_loss: 0.6306 - val_accuracy: 0.7886
# Epoch 42/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6053 - accuracy: 0.7899
# Epoch 42: val_accuracy did not improve from 0.81300
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.6052 - accuracy: 0.7900 - val_loss: 0.5974 - val_accuracy: 0.7983

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:20:53.969406

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
saved_model = load_model("best_cifa10.hdf5")
_, acc = saved_model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.920

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 79.460

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = saved_model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Colab Notebooks/h5_backups/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
