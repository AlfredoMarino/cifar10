# %% [markdown]
# <a href="https://colab.research.google.com/github/AlfredoMarino/cifar10/blob/main/cnn_cifar10_tf2_v8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model

from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
import random

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
#reshape into images
#img_rows, img_cols , channels= 32,32,3
#x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
#x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)
#input_shape = (img_rows, img_cols, 1)
#print('x_train shape:', x_train.shape)
#print(x_train.shape[0], 'train samples')
#print(x_test.shape[0], 'test samples')

# %%
#Normalizaremos
#mean = np.mean(x_train)
#std = np.std(x_train)

#x_train_scaled = (x_train - mean) / (std + 1e-7)
#x_test_scaled = (x_test - mean) / (std + 1e-7)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
y_test
# Out:
# array([[3],
#        [8],
#        [8],
#        ...,
#        [5],
#        [1],
#        [7]], dtype=uint8)

# %%
y_train = y_train.ravel()
y_test = y_test.ravel()

print("y_train", y_train)
print("y_test", y_test)
# Out:
# y_train [6 9 9 ... 9 1 1]
# y_test [3 8 8 ... 5 1 7]

# %%
y_train_label = y_train

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
  'airplane', # id 0
  'automobile',
  'bird',
  'cat',
  'deer',
  'dog',
  'frog',
  'horse',
  'ship',
  'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset CIFAR10

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ### Vemos ejemplos del data augumentation

# %%
train_batch_size = 32
val_batch_size = 20

# %%
# Data augmentation

train_datagen = ImageDataGenerator(
    rescale=(1./255),
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
)

train_generator = train_datagen.flow(
    x_train,
    y_train,
    batch_size=train_batch_size
)

validation_datagen = ImageDataGenerator(
    rescale=(1./255)
)

validation_generator = validation_datagen.flow(
    x_val,
    y_val,
    batch_size=val_batch_size
)

# %%
sample = random.choice(range(0,1457))

example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=20
)

plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Arquitectura de red del modelo - Proyecto 0

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.4))

model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_10 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_11 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_10 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_12 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  conv2d_20 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_13 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_11 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_14 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_15 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_9 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_13 (Dropout)        (None, 4, 4, 128)         0
#
#  conv2d_24 (Conv2D)          (None, 4, 4, 256)         295168
#
#  batch_normalization_16 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 4, 4, 256)         0
#
#  conv2d_25 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_17 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  conv2d_26 (Conv2D)          (None, 4, 4, 256)         590080
#
#  max_pooling2d_10 (MaxPoolin  (None, 2, 2, 256)        0
#  g2D)
#
#  dropout_15 (Dropout)        (None, 2, 2, 256)         0
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 256)               262400
#
#  dropout_16 (Dropout)        (None, 256)               0
#
#  dense_5 (Dense)             (None, 256)               65792
#
#  dense_6 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 2,244,522
# Trainable params: 2,242,602
# Non-trainable params: 1,920
# _________________________________________________________________

# %% [markdown]
# ## 4. Optimizador, función error

# %%
model.compile(
    optimizer='Adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# callback EarlyStopping basado en Accuracy
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience=10)

# callback EarlyStopping basadon en Loss
callback_loss = EarlyStopping(monitor='val_loss', patience=5)

# callback ModelCheckpoint basado en Accuracy
callback_checkpoint = ModelCheckpoint('best_cifa10.hdf5', verbose=1, save_best_only=True, monitor = 'val_accuracy')

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
print(f"x_train.shape[0]: {x_train.shape[0]}")
print(f"x_val.shape[0]: {x_val.shape[0]}")
# Out:
# x_train.shape[0]: 40000
# x_val.shape[0]: 10000

# %%
print(f"step_per_epoch: {x_train.shape[0] / train_batch_size}")
print(f"validation_steps: {x_val.shape[0] / val_batch_size}")
# Out:
# step_per_epoch: 1250.0
# validation_steps: 500.0

# %%
history = model.fit(
    train_generator,
    epochs=200,
    validation_data=validation_generator,
    steps_per_epoch=x_train.shape[0] // train_batch_size,
    validation_steps=x_val.shape[0] // val_batch_size,
    callbacks=[callback_checkpoint, callback_loss, callback_accuracy]
)
# Out:
# Epoch 1/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.9060 - accuracy: 0.2790
# Epoch 1: val_accuracy improved from -inf to 0.31200, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 30s 23ms/step - loss: 1.9059 - accuracy: 0.2792 - val_loss: 1.7953 - val_accuracy: 0.3120
# Epoch 2/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.6783 - accuracy: 0.3669
# Epoch 2: val_accuracy improved from 0.31200 to 0.41050, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.6781 - accuracy: 0.3670 - val_loss: 1.6223 - val_accuracy: 0.4105
# Epoch 3/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.5330 - accuracy: 0.4352
# Epoch 3: val_accuracy improved from 0.41050 to 0.43040, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 28s 23ms/step - loss: 1.5331 - accuracy: 0.4352 - val_loss: 1.5973 - val_accuracy: 0.4304
# Epoch 4/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.4122 - accuracy: 0.4933
# Epoch 4: val_accuracy improved from 0.43040 to 0.50370, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 28s 23ms/step - loss: 1.4120 - accuracy: 0.4934 - val_loss: 1.4145 - val_accuracy: 0.5037
# Epoch 5/200
# 1250/1250 [==============================] - ETA: 0s - loss: 1.3067 - accuracy: 0.5386
# Epoch 5: val_accuracy improved from 0.50370 to 0.53070, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 28s 22ms/step - loss: 1.3067 - accuracy: 0.5386 - val_loss: 1.4275 - val_accuracy: 0.5307
# Epoch 6/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2274 - accuracy: 0.5725
# Epoch 6: val_accuracy improved from 0.53070 to 0.61120, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 28s 23ms/step - loss: 1.2274 - accuracy: 0.5726 - val_loss: 1.0851 - val_accuracy: 0.6112
# Epoch 7/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1556 - accuracy: 0.5970
# Epoch 7: val_accuracy did not improve from 0.61120
# 1250/1250 [==============================] - 28s 22ms/step - loss: 1.1555 - accuracy: 0.5971 - val_loss: 1.0952 - val_accuracy: 0.6015
# Epoch 8/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1130 - accuracy: 0.6111
# Epoch 8: val_accuracy improved from 0.61120 to 0.62620, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 28s 23ms/step - loss: 1.1132 - accuracy: 0.6110 - val_loss: 1.0177 - val_accuracy: 0.6262
# Epoch 9/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0753 - accuracy: 0.6235
# Epoch 9: val_accuracy did not improve from 0.62620
# 1250/1250 [==============================] - 28s 23ms/step - loss: 1.0753 - accuracy: 0.6235 - val_loss: 1.1546 - val_accuracy: 0.5782
# Epoch 10/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0406 - accuracy: 0.6349
# Epoch 10: val_accuracy improved from 0.62620 to 0.65600, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 28s 23ms/step - loss: 1.0404 - accuracy: 0.6350 - val_loss: 0.9386 - val_accuracy: 0.6560
# Epoch 11/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.0111 - accuracy: 0.6484
# Epoch 11: val_accuracy improved from 0.65600 to 0.66170, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 28s 23ms/step - loss: 1.0109 - accuracy: 0.6485 - val_loss: 0.9669 - val_accuracy: 0.6617
# Epoch 12/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9830 - accuracy: 0.6573
# Epoch 12: val_accuracy did not improve from 0.66170
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.9830 - accuracy: 0.6573 - val_loss: 1.0808 - val_accuracy: 0.6089
# Epoch 13/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9670 - accuracy: 0.6646
# Epoch 13: val_accuracy did not improve from 0.66170
# 1250/1250 [==============================] - 28s 23ms/step - loss: 0.9674 - accuracy: 0.6645 - val_loss: 1.0122 - val_accuracy: 0.6420
# Epoch 14/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9377 - accuracy: 0.6735
# Epoch 14: val_accuracy improved from 0.66170 to 0.68440, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 28s 22ms/step - loss: 0.9377 - accuracy: 0.6735 - val_loss: 0.8958 - val_accuracy: 0.6844
# Epoch 15/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9352 - accuracy: 0.6786
# Epoch 15: val_accuracy improved from 0.68440 to 0.69800, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 28s 23ms/step - loss: 0.9351 - accuracy: 0.6786 - val_loss: 0.8549 - val_accuracy: 0.6980
# Epoch 16/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9069 - accuracy: 0.6863
# Epoch 16: val_accuracy did not improve from 0.69800
# 1250/1250 [==============================] - 28s 22ms/step - loss: 0.9069 - accuracy: 0.6863 - val_loss: 0.9062 - val_accuracy: 0.6795
# Epoch 17/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8833 - accuracy: 0.6953
# Epoch 17: val_accuracy did not improve from 0.69800
# 1250/1250 [==============================] - 28s 23ms/step - loss: 0.8833 - accuracy: 0.6953 - val_loss: 0.9243 - val_accuracy: 0.6776
# Epoch 18/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8694 - accuracy: 0.6974
# Epoch 18: val_accuracy improved from 0.69800 to 0.72000, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8692 - accuracy: 0.6975 - val_loss: 0.7901 - val_accuracy: 0.7200
# Epoch 19/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8590 - accuracy: 0.7040
# Epoch 19: val_accuracy improved from 0.72000 to 0.73980, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8591 - accuracy: 0.7038 - val_loss: 0.7400 - val_accuracy: 0.7398
# Epoch 20/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8485 - accuracy: 0.7076
# Epoch 20: val_accuracy did not improve from 0.73980
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8485 - accuracy: 0.7076 - val_loss: 0.8614 - val_accuracy: 0.7051
# Epoch 21/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8313 - accuracy: 0.7143
# Epoch 21: val_accuracy did not improve from 0.73980
# 1250/1250 [==============================] - 28s 23ms/step - loss: 0.8309 - accuracy: 0.7145 - val_loss: 0.8204 - val_accuracy: 0.7142
# Epoch 22/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8162 - accuracy: 0.7224
# Epoch 22: val_accuracy did not improve from 0.73980
# 1250/1250 [==============================] - 28s 23ms/step - loss: 0.8162 - accuracy: 0.7224 - val_loss: 0.8539 - val_accuracy: 0.7021
# Epoch 23/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.8098 - accuracy: 0.7225
# Epoch 23: val_accuracy did not improve from 0.73980
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.8097 - accuracy: 0.7225 - val_loss: 0.7808 - val_accuracy: 0.7297
# Epoch 24/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7995 - accuracy: 0.7303
# Epoch 24: val_accuracy improved from 0.73980 to 0.76460, saving model to best_cifa10.hdf5
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.7994 - accuracy: 0.7303 - val_loss: 0.6722 - val_accuracy: 0.7646
# Epoch 25/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7874 - accuracy: 0.7324
# Epoch 25: val_accuracy did not improve from 0.76460
# 1250/1250 [==============================] - 29s 23ms/step - loss: 0.7874 - accuracy: 0.7324 - val_loss: 0.8363 - val_accuracy: 0.7105
# Epoch 26/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7821 - accuracy: 0.7335
# Epoch 26: val_accuracy did not improve from 0.76460
# 1250/1250 [==============================] - 28s 23ms/step - loss: 0.7821 - accuracy: 0.7335 - val_loss: 0.9587 - val_accuracy: 0.6757
# Epoch 27/200
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7657 - accuracy: 0.7372
# Epoch 27: val_accuracy did not improve from 0.76460
# 1250/1250 [==============================] - 28s 23ms/step - loss: 0.7654 - accuracy: 0.7373 - val_loss: 0.6907 - val_accuracy: 0.7585
# Epoch 28/200
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7654 - accuracy: 0.7379
# Epoch 28: val_accuracy did not improve from 0.76460
# 1250/1250 [==============================] - 28s 23ms/step - loss: 0.7654 - accuracy: 0.7379 - val_loss: 0.7122 - val_accuracy: 0.7518
# Epoch 29/200
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7525 - accuracy: 0.7412
# Epoch 29: val_accuracy did not improve from 0.76460
# 1250/1250 [==============================] - 28s 23ms/step - loss: 0.7523 - accuracy: 0.7413 - val_loss: 0.7138 - val_accuracy: 0.7545

# %%
#history = model.fit(
#    x_train_scaled,
#    y_train,
#    epochs=100,
#    use_multiprocessing=False,
#    batch_size=128,
#    validation_data=(x_val_scaled, y_val),
#    callbacks=[callback_loss, callback_accuracy]
#)

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:13:46.738499

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
saved_model = load_model("best_cifa10.hdf5")
_, acc = saved_model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 76.010

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 74.660

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = saved_model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Colab Notebooks/h5_backups/" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.h5')
